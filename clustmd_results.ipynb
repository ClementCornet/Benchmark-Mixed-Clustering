# %%
from algorithms import pretopomd
import pandas as pd
from utils.gen_data import generate_data

# %%
df = generate_data(
    n_clusters=3,
    clust_std=0.1,
    n_num=15,
    n_cat=15,
    cat_unique=3,
    n_indiv=500
)

# %%
df['CLUSTER'] = pretopomd.process(df)
df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.137340 -0.031803 -0.148688 -0.350295 -0.000190 -0.104369  0.368278
# 1   -0.096866  0.131739  0.416404 -0.211869  0.041958 -0.040320 -0.126101
# 2   -0.015503  0.238281 -0.569544  0.222880  0.226549 -0.140846 -0.046860
# 3   -0.183261 -0.025760  0.087210 -0.147693 -0.197347  0.115196  0.130807
# 4   -0.085295  0.245788 -0.093839  0.125273 -0.202799 -0.309004  0.260795
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.169662  0.285503 -0.104114  0.040441  0.000140  0.037617  0.013064
# 996  0.109174  0.230784 -0.402509 -0.049563 -0.224952 -0.109958  0.069513
# 997  0.289895  0.228948 -0.232804 -0.129999 -0.007224  0.096378  0.127701
# 998  0.194722  0.096112  0.119000  0.059215 -0.176377 -0.007787  0.002829
# 999 -0.214167  0.072778  0.185786 -0.152663 -0.260338 -0.205853 -0.128166
#
#             7         8         9  ... 12 13 14 15 16 17 18 19 cluster CLUSTER
# ...

# %%
df.to_csv('PretopoMD_Results/15num_15cat_generated.csv')

# %%
df['CLUSTER'].value_counts()
# Out:
#  5    439
#  4    327
# -1    224
#  3      3
#  2      2
#  0      2
#  6      1
#  7      1
#  1      1
# Name: CLUSTER, dtype: int64
